# %% [markdown]
# # Lineáris Regresszió

# %%
# !pip install scikit-learn
# !pip install statsmodels
# Out:
# Requirement already satisfied: scikit-learn in /home/daniel/anaconda3/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/daniel/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /home/daniel/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/daniel/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/daniel/anaconda3/lib/python3.11/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: statsmodels in /home/daniel/anaconda3/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in /home/daniel/anaconda3/lib/python3.11/site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /home/daniel/anaconda3/lib/python3.11/site-packages (from statsmodels) (1.11.1)
# Requirement already satisfied: pandas>=1.0 in /home/daniel/anaconda3/lib/python3.11/site-packages (from statsmodels) (2.0.3)
# Requirement already satisfied: patsy>=0.5.2 in /home/daniel/anaconda3/lib/python3.11/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /home/daniel/anaconda3/lib/python3.11/site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/daniel/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/daniel/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/daniel/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in /home/daniel/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Adatok beolvasása

# %%
df = pd.read_csv('gdp_kisajatitas.csv')
df.head()
# Out:
#   shortnam  logpgp95    avexpr
# 0      AFG       NaN       NaN
# 1      AGO  7.770645  5.363637
# 2      ARE  9.804219  7.181818
# 3      ARG  9.133459  6.386363
# 4      ARM  7.682482       NaN

# %% [markdown]
# ### Adatok ábrázolása

# %%
plt.style.use('seaborn')

plt.figure(figsize=(6, 6))
plt.title("Országok kizsákmányolhatósága", size=20)
plt.scatter(x='logpgp95', y='avexpr', data=df)
plt.ylabel('Kizsákmányolhatóság', size=15)
plt.xlabel("GDP", size=15)
plt.show()

# %% [markdown]
# ### Adatok tisztítása

# %%
df_clean = df.dropna().copy()
df_clean['const'] = 1 # az y tengelymetszet nem lehet 0, mert nincs 0 GDP ország

# Változók felvétele
x = df_clean.loc[:, 'logpgp95']
y = df_clean.loc[:, 'avexpr']
labels = df_clean.loc[:, 'shortnam']

df_clean.head()
# Out:
#   shortnam  logpgp95    avexpr  const
# 1      AGO  7.770645  5.363637      1
# 2      ARE  9.804219  7.181818      1
# 3      ARG  9.133459  6.386363      1
# 5      AUS  9.897972  9.318182      1
# 6      AUT  9.974877  9.727273      1

# %% [markdown]
# ### Rergressziós modell felállítása

# %%
reg1 = sm.OLS(endog=y, exog=df_clean[['const', 'avexpr']]) #endog: függő változó, exog: független változó

print("Reg1 type:")
print(type(reg1))

# A tanítás eljárása
results = reg1.fit()

type(results)

# A modell
print(results.summary())
# Out:
# Reg1 type:
# <class 'statsmodels.regression.linear_model.OLS'>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 avexpr   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.179e+32
# Date:                Mon, 04 Dec 2023   Prob (F-statistic):               0.00
# Time:                        17:09:05   Log-Likelihood:                 3623.2
# No. Observations:                 111   AIC:                            -7242.
# Df Residuals:                     109   BIC:                            -7237.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -1.11e-16   6.81e-16     -0.163      0.871   -1.46e-15    1.24e-15
# avexpr         1.0000   9.21e-17   1.09e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                       22.404   Durbin-Watson:                   0.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.975
# Skew:                           1.255   Prob(JB):                     3.10e-07
# Kurtosis:                       2.575   Cond. No.                         33.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Lineáris trendvonal illesztése

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(x, y, marker='')

for i, label in enumerate(labels):
    ax.annotate(label, (x.iloc[i], y.iloc[i]))
    
line = np.poly1d(np.polyfit(x, y, 1))(np.unique(x))
ax.plot(np.unique(x), line, color='black')

ax.set_title("Lineáris modell", size=20)
ax.set_xlabel("GDP", size=15)
ax.set_ylabel("Kizsákmányolhatóság", size=15)
plt.show()

# %% [markdown]
# ### Predikciók készítése

# %%
fig, ax = plt.subplots(figsize=(6,6))

ax.scatter(df_clean['avexpr'], results.predict(), alpha=0.8, label='predicted')

ax.scatter(df_clean['avexpr'], df_clean['logpgp95'], alpha=0.8, label='observed')

ax.legend()
ax.set_title("Egyedi pontokhoz tartozó predikciók", size=20)
ax.set_xlabel("GDP", size=15)
ax.set_ylabel("Kizsákmányolhatóság", size=15)
plt.show()

# %% [markdown]
# ### Gradiens ereszkedés: a kezdeti egyenes felvétele

# %%
#Egyenes ábrázolása
def plotf():
    plt.figure(figsize=(6, 6))
    plt.scatter(x, y)
    plt.plot(x, f, color='red')

# %%
# Paraméterek felvétele
b0 = 0
b1 = 0

#Egyenes egyenlete
f = b0 + b1*x

#Eltérés-négyzet
print("Hiba:", np.sum((f - y)**2))

plotf()
# Out:
# Hiba: 6077.470065214054

# %% [markdown]
# ### b0 és b1 közelítése az optimálishoz

# %%
#Tanulási sebesség
alpha = 0.00001

b0 = b0 - np.sum(2*(b0 + b1*x - y))*alpha
b1 = b1 - np.sum(2*(b0 + b1*x - y)*x)*alpha

# Regresszió fgv újraszámolása
f = b0 + b1*x

print('b0: ', b0, ' b1: ', b1)
print('Hiba:', np.sum((f - y)**2))

plotf()
# Out:
# b0:  0.015999090934000003  b1:  0.13836141540684668
# Hiba: 4292.338407494591

# %% [markdown]
# ### Hiba számolása ciklikusan

# %%
b0=0
b1=0

hibakovetes = []
alpha = 0.00001

for i in range(1000):
    b0 = b0 - np.sum(2*(b0 + b1*x - y))*alpha
    b1 = b1 - np.sum(2*(b0 + b1*x - y)*x)*alpha
    hibakovetes.append(np.sum((b0 + b1*x - y)**2))
    
    
f = b0 + b1*x
print('b0: ', b0, ' b1: ', b1)
print('Hiba: ', np.sum((f - y)**2))
plotf()
# Out:
# b0:  -0.0021552025202711224  b1:  0.8574567494266527
# Hiba:  133.9441323155976

# %% [markdown]
# ### A számolt hiba ábrázolása

# %%
plt.figure(figsize=(6, 6))
plt.scatter(np.linspace(0, len(hibakovetes), len(hibakovetes)), hibakovetes)
plt.title('Hiba követése iterációkon keresztül')
plt.show()

# %% [markdown]
# ### Hiba változása százalékban kifejezve, az első száz elemre

# %%
hibaszazalek = []
for i in range(1, len(hibakovetes)):
    hibaszazalek.append(hibakovetes[i-1] / hibakovetes[i])

hibaszazalek = hibaszazalek[:100]
plt.figure(figsize=(6, 6))
plt.scatter(np.linspace(0, len(hibaszazalek), len(hibaszazalek)), hibaszazalek)
plt.title('Hiba követése arányosan (%)')
plt.show()
